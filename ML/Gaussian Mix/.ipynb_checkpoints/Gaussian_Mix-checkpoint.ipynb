# %%
import numpy as np
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pandas as pd
from random import uniform

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
X, _= make_blobs(n_samples=100, centers=2, n_features=2,
                   random_state=6)
df = pd.DataFrame(X, columns=['x','y'])
plt.scatter(X[:,0],X[:,1])

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
class Gaussian:
    "Model for multivariate Gaussian"
    def __init__(self, mu, sigma):
        self.mu = mu
        self.sigma = sigma
        
    "PDF"
    def pdf(self, x):
        diff = x - self.mu
        dim = len(self.mu)
        det_half = np.linalg.det(self.sigma) ** 0.5
        inv = np.linalg.inv(self.sigma)
        return (1./(2 * np.pi) ** (dim/2) * det_half) * np.exp(-1/2 * np.dot(np.dot(diff.T, inv), diff))
    
    def __repr__(self):
        return 'Gaussian mu={:.4}'.format(self.mu)

# %%
test_gaussian, _= make_blobs(n_samples=100, centers=1, n_features=2,
                   random_state=8)
df_test = pd.DataFrame(test_gaussian, columns=['x','y'])
sns.jointplot(x="x", y="y", data=df_test, kind="kde",xlim=[4,10], ylim=[6,13]);

# %%
mu = df_test.mean().as_matrix()
sigma = df_test.cov().as_matrix()
gaus = Gaussian(mu, sigma)

# %%
M = 100
X_grid = np.linspace(4,10, M)
Y_grid = np.linspace(6,13,M)
X_plot, Y_plot = np.meshgrid(X_grid, Y_grid)

# %%
Z = np.zeros(( M, M))
for i, x_val in enumerate(X_grid):
    for j, y_val in enumerate(Y_grid):
        Z[i,j] = gaus.pdf(np.array([x_val, y_val]))

# %%
cmap = plt.cm.get_cmap("jet")
cmap.set_over('grey')
cl = plt.contourf(X_plot, Y_plot, Z.T,cmap=cmap)
plt.axis('equal')
plt.colorbar(cl)

# %%
class GaussianMixed:
    def __init__(self, data, sigma_min=.1, sigma_max=1., mix=.5):
        self.data = data
        mu_min=np.min(data)
        mu_max=np.max(data)
        self.one = Gaussian(uniform(mu_min, mu_max) * np.ones(2), 
                            uniform(sigma_min, sigma_max) * np.ones((2,2)))
        self.two = Gaussian(uniform(mu_min, mu_max) * np.ones(2), 
                            uniform(sigma_min, sigma_max) * np.ones((2,2)))
        
        self.mix = mix
    
    def Estep(self):
        
        self.loglike = 0
        for datum in data:
            # Unnormalized
            w1 = self.one.pdf(datum) * self.mix
            w2 = self.two.pdf(datum) * (1 - self.mix)
            
            # ตัวเศษ
            den = w1 + w2
            
            # Normalized
            w1 /= den
            w2 /= den
            
            # log-likelyhood
            self.loglike += np.log(w1) + np.log(w2)
            
            yield (w1, w2)
            
    def Mstep(self, weights):
        l, r = zip(*weights)
        l, r = np.array(l), np.array(r)
        
        one_den = sum(l)
        two_den = sum(r)
        
        self.mix = one_den / len(self.data)
        
        self.one.mu = np.sum(self.data.T * l, axis = 1) / one_den
        self.two.mu = np.sum(self.data.T * r, axis=1) / two_deon
        
        l_diff = self.data - self.one.mu
        r_diff = self.data - self.two.mu
        self.one.sigma = np.dot(l_diff.T * np.array(l), l_diff) / one_den
        self.two.sigma = np.dot(r_diff.T * np.array(r), r_diff) / two_den
        
    def pdf(self, x):
        return self.mix * self.one.pdf(x) + (1 - self.mix) * self.two.pdf(x)
    
    def iterate(self, N=1, verbose=False):
        raise NotImplementedError
